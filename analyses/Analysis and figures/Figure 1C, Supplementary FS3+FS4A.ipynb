# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns



plt.rcParams['font.family'] = 'Arial'
growth_curvesA=pd.read_excel(r'C:\Users\yaras\OneDrive\Desktop\Analysis for paper\Growth curves\Growth curves of Group A- for python.xlsx')
growth_curvesB=pd.read_excel(r'C:\Users\yaras\OneDrive\Desktop\Analysis for paper\Growth curves\Growth curves of Group B- for python.xlsx')
growth_curvesC=pd.read_excel(r'C:\Users\yaras\OneDrive\Desktop\Analysis for paper\Growth curves\Growth curves of Group C- for python.xlsx')
growth_curvesD=pd.read_excel(r'C:\Users\yaras\OneDrive\Desktop\Analysis for paper\Growth curves\Growth curves of Group D- for python.xlsx')

# %%
growth_curvesA=growth_curvesA.drop(growth_curvesA.index[:2])
growth_curvesB=growth_curvesB.drop(growth_curvesB.index[:2])
growth_curvesC=growth_curvesC.drop(growth_curvesC.index[:2])
growth_curvesD=growth_curvesD.drop(growth_curvesD.index[:2])

# %%
growth_curvesB.head()
# Out:
#                  Date       Day     B1     B2     B3     B4     B5     B6  \
# 2 2022-12-11 14:06:00         0  0.119  0.197  0.194  0.145  0.147  0.173
# 3 2022-12-12 11:52:00  0.906944  0.178  0.236  0.184  0.247   0.18  0.218
# 4 2022-12-13 10:17:00  1.840972  0.336   0.25  0.284  0.308   0.27  0.285
# 5 2022-12-14 22:28:00  3.348611  0.539  0.586  0.509  0.592  0.571  0.584
# 6 2022-12-15 10:29:00  3.849306  0.777  0.673   0.79  0.815   0.72   0.72
#
#       B7     B8  ...    B63    B64    B65    B66    B67    B68    B69    B70  \
# 2  0.198  0.225  ...  0.243  0.273  0.331  0.225  0.212  0.272  0.353  0.305
# 3  0.208  0.186  ...  0.351  0.206   0.21  0.166  0.324  0.348  0.352  0.137
# 4  0.249  0.302  ...  0.474  0.232  0.256  0.207  0.403  0.356  0.381  0.151
# 5   0.53  0.551  ...  0.787   0.41  0.318  0.331  0.656  0.715  0.621  0.052
# 6  0.805  0.735  ...  1.077  0.491  0.493  0.448  0.813  0.856  0.818  0.089
#
#      B71    B72
# 2  0.437  0.292
# 3  0.226  0.201
# ...

# %% [markdown]
# # Figure 1C

# %%
plt.figure(figsize=(15, 10))


plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)


plt.subplot(3,3,1)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5) 
plt.plot(growth_curvesB['Day'], growth_curvesB['B1'], color='#117733', label='PRO99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B2'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B3'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B4'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B5'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B6'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B7'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B8'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B9'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B10'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B11'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B12'], color='#003399')
plt.title('MED4', fontsize=20, color='black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)


plt.subplot(3,3,2)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.plot(growth_curvesB['Day'], growth_curvesB['B25'], color='#117733', label='PRO99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B26'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B27'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B28'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B29'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B30'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B31'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B32'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B33'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B34'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B35'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B36'], color='#003399')
plt.title('MIT9515', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(3,3,3)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A37'], color='#117733', label='PRO99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A38'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A39'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A28'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A29'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A30'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A31'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A32'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A33'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A34'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A35'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A36'], color='#003399')
plt.title('MIT1327', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)



handles, labels = plt.gca().get_legend_handles_labels()

# Create custom legend handles as rectangles
custom_handles = [mpatches.Rectangle((0, 0), 1, 1, facecolor='#117733'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#D55E00'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#56B4E9'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#003399')]
plt.legend(custom_handles, labels, loc='upper center', bbox_to_anchor=(-1, 1.4), fontsize='xx-large', frameon=False, ncol=5)

plt.savefig('graph_paper', dpi=128, bbox_inches='tight')

# %% [markdown]
# # Supplementary Figure S3

# %%
plt.figure(figsize=(20, 15))

# Adjust subplot parameters for better spacing
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)

plt.subplot(4, 4, 1)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A13'], color='#117733', label='PRO99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A14'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A15'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A16'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A17'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A18'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A19'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A20'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A21'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A22'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A23'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A24'], color='#003399')
plt.title('MIT9312', fontsize=20, color='black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4, 4, 2)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A25'], color='#117733', label='PRO99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A26'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A27'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A28'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A29'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A30'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A31'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A32'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A33'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A34'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A35'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A36'], color='#003399')
plt.title('MIT9313', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 3)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A49'], color='#117733', label='PRO99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A50'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A51'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A52'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A53'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A54'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A55'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A56'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A57'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A58'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A59'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A60'], color='#003399')
plt.title('MIT0604', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 4)
plt.yscale("log")
plt.ylim(10**-2, 10**1)

plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)
plt.xlim(0, 90)
plt.plot(growth_curvesA['Day'], growth_curvesA['A61'], color='#117733', label='PRO99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A62'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A63'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A64'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A65'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A66'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A67'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A68'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A69'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A70'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A71'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A72'], color='#003399')
plt.title('NATL2A', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

# Get handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create custom legend handles as rectangles
custom_handles = [mpatches.Rectangle((0, 0), 1, 1, facecolor='#117733'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#D55E00'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#56B4E9'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#003399')]
plt.legend(custom_handles, labels, loc='upper center', bbox_to_anchor=(-1.7, 1.4), fontsize='xx-large', frameon=False, ncol=5)

plt.savefig('graph_paper_sup1', dpi=128, bbox_inches='tight')

# %%
plt.figure(figsize=(20, 15))

# Adjust subplot parameters for better spacing
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)

plt.subplot(4, 4, 1)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesB['Day'], growth_curvesB['B37'], color='#117733', label='Pro99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B38'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B39'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B40'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B41'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B42'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B43'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B44'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B45'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B46'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B47'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B48'], color='#003399')
plt.title('MIT9215', fontsize=20, color='black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4, 4, 2)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesB['Day'], growth_curvesB['B49'], color='#117733', label='Pro99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B50'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B51'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B52'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B53'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B54'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B55'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B56'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B57'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B58'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B59'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B60'], color='#003399')
plt.title('AS9601', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 3)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesB['Day'], growth_curvesB['B61'], color='#117733', label='Pro99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B62'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B63'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B64'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B65'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B66'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B67'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B68'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B69'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B70'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B71'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B72'], color='#003399')
plt.title('PAC1', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 4)
plt.yscale("log")
plt.ylim(10**-2, 10**1)
plt.xlim(0, 90)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesC['Day'], growth_curvesC['C25'], color='#117733', label='Pro99')
plt.plot(growth_curvesC['Day'], growth_curvesC['C26'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C27'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C28'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C29'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C30'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C31'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C32'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C33'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C34'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C35'], color='#003399')
plt.plot(growth_curvesC['Day'], growth_curvesC['C36'], color='#003399')
plt.title('MIT9202', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

# Get handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create custom legend handles as rectangles
custom_handles = [mpatches.Rectangle((0, 0), 1, 1, facecolor='#117733'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#D55E00'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#56B4E9'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#003399')]
# plt.legend(custom_handles, labels, loc='upper center', bbox_to_anchor=(-1.7, 1.4), fontsize='xx-large', frameon=False, ncol=5)

plt.savefig('graph_paper_sup2', dpi=128, bbox_inches='tight')

# %%
plt.figure(figsize=(20, 15))

# Adjust subplot parameters for better spacing
plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9, top=0.9, wspace=0.4, hspace=0.4)

plt.subplot(4, 4, 1)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesC['Day'], growth_curvesC['C37'], color='#117733', label='Pro99')
plt.plot(growth_curvesC['Day'], growth_curvesC['C38'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C39'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C40'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C41'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C42'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C43'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C44'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C45'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C46'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C47'], color='#003399')
plt.plot(growth_curvesC['Day'], growth_curvesC['C48'], color='#003399')
plt.title('SB', fontsize=20, color='black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4, 4, 2)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesD['Day'], growth_curvesD['D25'], color='#117733', label='Pro99')
plt.plot(growth_curvesD['Day'], growth_curvesD['D26'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D27'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D28'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D29'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D30'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D31'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D32'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D33'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D34'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D35'], color='#003399')
plt.plot(growth_curvesD['Day'], growth_curvesD['D36'], color='#003399')
plt.title('MIT9301', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 3)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesD['Day'], growth_curvesD['D37'], color='#117733', label='Pro99')
plt.plot(growth_curvesD['Day'], growth_curvesD['D38'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D39'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D40'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D41'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D42'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D43'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D44'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D45'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D46'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D47'], color='#003399')
plt.plot(growth_curvesD['Day'], growth_curvesD['D48'], color='#003399')
plt.title('MIT1314', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

plt.subplot(4,4, 4)
plt.yscale("log")
plt.ylim(10**-2, 10**1)
plt.xlim(0, 90)
plt.axhline(y=0.1, color='gray', linestyle='--', linewidth=1.5)

plt.plot(growth_curvesD['Day'], growth_curvesD['D49'], color='#117733', label='Pro99')
plt.plot(growth_curvesD['Day'], growth_curvesD['D50'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D51'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D52'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D53'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D54'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D55'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D56'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D57'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D58'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D59'], color='#003399')
plt.plot(growth_curvesD['Day'], growth_curvesD['D60'], color='#003399')
plt.title('NATL1A', fontsize=20, color= 'black')
plt.ylabel('FL (au)', fontsize=18)
plt.xlabel('Time (Days)', fontsize=18)
plt.tick_params(axis='x', color='black', labelsize=12.5)
plt.tick_params(axis='y', color='black', labelsize=12.5)

# Get handles and labels
handles, labels = plt.gca().get_legend_handles_labels()

# Create custom legend handles as rectangles
custom_handles = [mpatches.Rectangle((0, 0), 1, 1, facecolor='#117733'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#D55E00'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#56B4E9'),
                  mpatches.Rectangle((0, 0), 1, 1, facecolor='#003399')]
# plt.legend(custom_handles, labels, loc='upper center', bbox_to_anchor=(-1.7, 1.4), fontsize='xx-large', frameon=False, ncol=5)

plt.savefig('graph_paper_sup3', dpi=128, bbox_inches='tight')

# %% [markdown]
# # Supplementary Figure S4A

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# Initialize a single large figure for a 2x4 grid layout
plt.figure(figsize=(25, 13))

# Adjust parameters for clean spacing across the 2-row grid
plt.subplots_adjust(left=0.08, bottom=0.1, right=0.92, top=0.84, wspace=0.35, hspace=0.45)

# Subplot 1: MED4 Experiment 1
plt.subplot(2, 4, 1)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A1'], color='#117733', label='Pro99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A2'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A3'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A4'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A5'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A6'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A7'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A8'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A9'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A10'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A11'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A12'], color='#003399')
plt.title('MED4 - Experiment 1', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 2: MED4 Experiment 2
plt.subplot(2, 4, 2)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesB['Day'], growth_curvesB['B1'], color='#117733', label='Pro99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B2'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B3'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B4'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B5'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B6'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B7'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B8'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B9'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B10'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B11'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B12'], color='#003399')
plt.title('MED4 - Experiment 2', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 3: MED4 Experiment 3
plt.subplot(2, 4, 3)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesC['Day'], growth_curvesC['C1'], color='#117733', label='Pro99')
plt.plot(growth_curvesC['Day'], growth_curvesC['C2'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C3'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C4'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C5'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C6'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C7'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C8'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C9'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C10'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C11'], color='#003399')
plt.plot(growth_curvesC['Day'], growth_curvesC['C12'], color='#003399')
plt.title('MED4 - Experiment 3', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 4: MED4 Experiment 4
plt.subplot(2, 4, 4)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesD['Day'], growth_curvesD['D1'], color='#117733', label='Pro99')
plt.plot(growth_curvesD['Day'], growth_curvesD['D2'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D3'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D4'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D5'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D6'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D7'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D56'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D57'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D58'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D59'], color='#003399')
plt.plot(growth_curvesD['Day'], growth_curvesD['D60'], color='#003399')
plt.title('MED4 - Experiment 4', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)



# Subplot 5: MIT9312 Experiment 1
plt.subplot(2, 4, 5)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesA['Day'], growth_curvesA['A13'], color='#117733', label='Pro99')
plt.plot(growth_curvesA['Day'], growth_curvesA['A14'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A15'], color='#117733')
plt.plot(growth_curvesA['Day'], growth_curvesA['A16'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A17'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A18'], color='#D55E00')
plt.plot(growth_curvesA['Day'], growth_curvesA['A19'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A20'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A21'], color='#56B4E9')
plt.plot(growth_curvesA['Day'], growth_curvesA['A22'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesA['Day'], growth_curvesA['A23'], color='#003399')
plt.plot(growth_curvesA['Day'], growth_curvesA['A24'], color='#003399')
plt.title('MIT9312 - Experiment 1', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 6: MIT9312 Experiment 2
plt.subplot(2, 4, 6)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesB['Day'], growth_curvesB['B13'], color='#117733', label='Pro99')
plt.plot(growth_curvesB['Day'], growth_curvesB['B14'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B15'], color='#117733')
plt.plot(growth_curvesB['Day'], growth_curvesB['B16'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B17'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B18'], color='#D55E00')
plt.plot(growth_curvesB['Day'], growth_curvesB['B19'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B20'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B21'], color='#56B4E9')
plt.plot(growth_curvesB['Day'], growth_curvesB['B22'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesB['Day'], growth_curvesB['B23'], color='#003399')
plt.plot(growth_curvesB['Day'], growth_curvesB['B24'], color='#003399')
plt.title('MIT9312 - Experiment 2', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 7: MIT9312 Experiment 3
plt.subplot(2, 4, 7)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesC['Day'], growth_curvesC['C13'], color='#117733', label='Pro99')
plt.plot(growth_curvesC['Day'], growth_curvesC['C14'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C15'], color='#117733')
plt.plot(growth_curvesC['Day'], growth_curvesC['C16'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C17'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C18'], color='#D55E00')
plt.plot(growth_curvesC['Day'], growth_curvesC['C19'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C20'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C21'], color='#56B4E9')
plt.plot(growth_curvesC['Day'], growth_curvesC['C22'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesC['Day'], growth_curvesC['C23'], color='#003399')
plt.plot(growth_curvesC['Day'], growth_curvesC['C24'], color='#003399')
plt.title('MIT9312 - Experiment 3', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)

# Subplot 8: MIT9312 Experiment 4
plt.subplot(2, 4, 8)
plt.yscale("log")
plt.xlim(0, 90)
plt.ylim(10**-2, 10**1)
plt.axhline(y=10**-1, color='gray', linestyle='--', alpha=0.7, linewidth=1.5)
plt.plot(growth_curvesD['Day'], growth_curvesD['D13'], color='#117733', label='Pro99')
plt.plot(growth_curvesD['Day'], growth_curvesD['D14'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D15'], color='#117733')
plt.plot(growth_curvesD['Day'], growth_curvesD['D16'], color='#D55E00', label='lowN (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D17'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D18'], color='#D55E00')
plt.plot(growth_curvesD['Day'], growth_curvesD['D19'], color='#56B4E9', label='lowP (1:8)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D20'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D21'], color='#56B4E9')
plt.plot(growth_curvesD['Day'], growth_curvesD['D22'], color='#003399', label='lowP (1:50)')
plt.plot(growth_curvesD['Day'], growth_curvesD['D23'], color='#003399')
plt.plot(growth_curvesD['Day'], growth_curvesD['D24'], color='#003399')
plt.title('MIT9312 - Experiment 4', fontsize=22, color='black', pad=12)
plt.ylabel('FL (au)', fontsize=22)
plt.xlabel('Time (Days)', fontsize=22)
plt.tick_params(axis='x', color='black', labelsize=16)
plt.tick_params(axis='y', color='black', labelsize=16)


labels = ['PRO99', 'lowN (1:8)', 'lowP (1:8)', 'lowP (1:50)']

custom_handles = [
    mpatches.Rectangle((0, 0), 1, 1, facecolor='#117733'),
    mpatches.Rectangle((0, 0), 1, 1, facecolor='#D55E00'),
    mpatches.Rectangle((0, 0), 1, 1, facecolor='#56B4E9'),
    mpatches.Rectangle((0, 0), 1, 1, facecolor='#003399')
]

# Create one shared global legend centered above the 2 rows
fig = plt.gcf()
fig.legend(
    custom_handles, labels, 
    loc='upper center', 
    bbox_to_anchor=(0.5, 0.94), 
    fontsize=26, 
    frameon=False, 
    ncol=4
)

# Export clean high-resolution figure
plt.savefig('combined_MED4_MIT9312_grid.png', dpi=128, bbox_inches='tight')
plt.show()
